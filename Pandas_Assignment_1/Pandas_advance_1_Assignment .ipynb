# %% [markdown]
# ## Q1. List any five functions of the pandas library with execution.

# %% [markdown]
# **Below listed are the following 5 functions:**
#  1. `read()`
#  2. `head()`
#  3. `tail()`
#  4. `dtypes`
#  5. `columns`

# %% [markdown]
# 1. `read()`
# Its is used to read various types of files aslike csv,json,feather etc.

# %%
import pandas as pd

# %%
df = pd.read_csv("services-Copy1.csv")
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %% [markdown]
# 2. `head()`:
# Returns the first 5 columns in a dataframe.

# %%
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %% [markdown]
# 3. `tail()`:
# Returns the last 5 columns in a dataframe.

# %%
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %% [markdown]
# 4. `dtypes`:
# Returns the datatypes of dataframes like int,object.

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %% [markdown]
# 5. `columns`:
# Returns the name of the columns

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %% [markdown]
# ## Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
import pandas as pd

def reindex_df(df):
    new_index = range(1, len(df) * 2, 2)
    df = df.set_index(pd.Index(new_index))
    return df

# %%
#Example usage:
#Assuming df is your Pandas DataFrame with columns 'A', 'B', and 'C'
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df = reindex_df(df)
df
# Out:
#    A  B  C
# 1  1  4  7
# 3  2  5  8
# 5  3  6  9

# %% [markdown]
# ## Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console.
#
# ## For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should calculate and print the sum of the first three values, which is 60.

# %%
def sum_first_three_values(df):
    first_three_values = df['Values'].head(3)
    total_sum = first_three_values.sum()
    print("Sum of first three values",total_sum)

# %%
# Example usage:
# Assuming df is your Pandas DataFrame with a column named 'Values'
df = pd.DataFrame({'Values': [10, 20, 30, 40, 50]})
df
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
sum_first_three_values(df)
# Out:
# Sum of first three values 60

# %% [markdown]
# ## Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df = pd.DataFrame({"Text":["My name is Shreyash","I m learning Machine Learning"]})

# %%
df
# Out:
#                             Text
# 0            My name is Shreyash
# 1  I m learning Machine Learning

# %%
def add_word_count_column(df):
    def word_count(text):
        return len(text.split())
    
    df["Word_count"]=df["Text"].apply(word_count)
    return df

# %%
df
# Out:
#                             Text
# 0            My name is Shreyash
# 1  I m learning Machine Learning

# %%
add_word_count_column(df)
# Out:
#                             Text  Word_count
# 0            My name is Shreyash           4
# 1  I m learning Machine Learning           5

# %% [markdown]
# ## Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# **DataFrame.size and DataFrame.shape are both attributes of Pandas DataFrames, but they serve different purposes:**
#
# **DataFrame.size:** This attribute returns the total number of elements in the DataFrame, which is equal to the number of rows multiplied by the number of columns. It calculates the size in terms of the total number of data points in the DataFrame.
#
# **DataFrame.shape:** This attribute returns a tuple representing the dimensions of the DataFrame. The tuple contains two elements: the number of rows and the number of columns, respectively. So, DataFrame.shape[0] gives the number of rows, and DataFrame.shape[1] gives the number of columns.
#
# **Here's a quick summary:**
#
# **DataFrame.size: Returns the total number of elements (rows * columns).**
#
# **DataFrame.shape: Returns a tuple representing the dimensions (number of rows, number of columns).**

# %%
df = pd.DataFrame({"A":[1,2,3],"B":[4,5,6]})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
print("DataFrame Size: ",df.size)
print("DataFrame Shape: ",df.shape)
# Out:
# DataFrame Size:  6
# DataFrame Shape:  (3, 2)

# %% [markdown]
# ## Q6. Which function of pandas do we use to read an excel file?

# %% [markdown]
# In Pandas, we used `.read_excel()` to read excel file.

# %%
pd.read_excel("Example.xlsx")
# Out:
#    Employee_id       Name  Designation
# 0          101    Utkarsh    Developer
# 1          102      Seema    Architect
# 2          103      Aditi  QA (Tester)
# 3          104      Nitin   Operations
# 4          105  Sudhanshu      Manager

# %% [markdown]
# ## Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %%
#create sample dataframe
df = pd.DataFrame({
    'Email':["shreyash.028@gmail.com","username@gmail.com","john.doe@example.com"]
})

# %%
#Sample dataframe 
df
# Out:
#                     Email
# 0  shreyash.028@gmail.com
# 1      username@gmail.com
# 2    john.doe@example.com

# %%
def add_username(df):
    def username(Email):
        return Email.split("@")[0]
    df["Username"]=df["Email"].apply(username)
    return df

# %%
df
# Out:
#                     Email
# 0  shreyash.028@gmail.com
# 1      username@gmail.com
# 2    john.doe@example.com

# %%
add_username(df)
# Out:
#                     Email      Username
# 0  shreyash.028@gmail.com  shreyash.028
# 1      username@gmail.com      username
# 2    john.doe@example.com      john.doe

# %% [markdown]
# ## Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows.

# %%
import pandas as pd

def select_rows(df):
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]
    return selected_rows

# %%
# Example usage:
# Assuming df is your Pandas DataFrame with columns 'A', 'B', and 'C'
df = pd.DataFrame({'A': [3, 6, 8, 2], 'B': [9, 5, 7, 11], 'C': [12, 15, 10, 8]})
selected_df = select_rows(df)
df
# Out:
#    A   B   C
# 0  3   9  12
# 1  6   5  15
# 2  8   7  10
# 3  2  11   8

# %%
selected_df
# Out:
#    A  B   C
# 1  6  5  15
# 2  8  7  10

# %% [markdown]
# ## Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,median, and standard deviation of the values in the 'Values' column.

# %%
def calculate_stats(df):
    mean = df['Values'].mean()
    median = df['Values'].median()
    std_deviation = df['Values'].std()
    return mean,median,std_deviation

# %%
import pandas as pd 
df = pd.DataFrame({"Values":[2,4,6,8,10]})
df
# Out:
#    Values
# 0       2
# 1       4
# 2       6
# 3       8
# 4      10

# %%
mean,median,std_dev= calculate_stats(df)
print(f"Mean of Values :{mean}")
print(f"Median of Values :{median}")
print(f"Standard Deviation of Values :{round(std_dev,4)}")
# Out:
# Mean of Values :6.0
# Median of Values :6.0
# Standard Deviation of Values :3.1623

# %% [markdown]
# ## Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %%
import pandas as pd

def calculate_moving_average(df):
    # sort the DataFrame by date
    df = df.sort_values(by='Date')

    # calculate the moving average using a rolling window of size 7
    df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()

    return df

# %%
df = pd.DataFrame({
    'Date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08', '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12'],
    'Sales': [11, 15, 35, 41, 42, 64, 72, 51, 65, 81, 95, 111]
})

df = calculate_moving_average(df)

# %%
df_new = calculate_moving_average(df)
df_new
# Out:
#           Date  Sales  MovingAverage
# 0   2022-01-01     11      11.000000
# 1   2022-01-02     15      13.000000
# 2   2022-01-03     35      20.333333
# 3   2022-01-04     41      25.500000
# 4   2022-01-05     42      28.800000
# 5   2022-01-06     64      34.666667
# 6   2022-01-07     72      40.000000
# 7   2022-01-08     51      45.714286
# 8   2022-01-09     65      52.857143
# 9   2022-01-10     81      59.428571
# 10  2022-01-11     95      67.142857
# 11  2022-01-12    111      77.000000

# %% [markdown]
# ## Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a newcolumn 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.Monday, Tuesday) corresponding to each date in the 'Date' column.

# %%
import pandas as pd 
def return_weekdays(df):
    df['Date']= pd.to_datetime(df['Date'])
    #returns weekday
    df['Weekday']=df['Date'].dt.day_name()
    return df

# %%
df = pd.DataFrame({'Date':['2023-01-01','2023-01-02','2023-01-03','2023-01-04','2023-01-05']})
df
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
new_df = return_weekdays(df)
new_df
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# ## Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
def select_january_rows(df):
    # Convert 'Date' column to pandas datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Select rows with dates between '2023-01-01' and '2023-01-31'
    january_rows = df[df['Date'].between('2023-01-01', '2023-01-31')]
    
    return january_rows

# %%
df = pd.DataFrame({'Date':pd.date_range(start='12/1/2022',end='3/1/2023',freq='D')})
df
# Out:
#          Date
# 0  2022-12-01
# 1  2022-12-02
# 2  2022-12-03
# 3  2022-12-04
# 4  2022-12-05
# ..        ...
# 86 2023-02-25
# 87 2023-02-26
# 88 2023-02-27
# 89 2023-02-28
# 90 2023-03-01
#
# [91 rows x 1 columns]

# %%
select_january_rows(df)
# Out:
#          Date
# 31 2023-01-01
# 32 2023-01-02
# 33 2023-01-03
# 34 2023-01-04
# 35 2023-01-05
# 36 2023-01-06
# 37 2023-01-07
# 38 2023-01-08
# 39 2023-01-09
# 40 2023-01-10
# 41 2023-01-11
# 42 2023-01-12
# 43 2023-01-13
# 44 2023-01-14
# 45 2023-01-15
# 46 2023-01-16
# 47 2023-01-17
# 48 2023-01-18
# 49 2023-01-19
# 50 2023-01-20
# 51 2023-01-21
# 52 2023-01-22
# 53 2023-01-23
# 54 2023-01-24
# 55 2023-01-25
# 56 2023-01-26
# 57 2023-01-27
# 58 2023-01-28
# 59 2023-01-29
# 60 2023-01-30
# 61 2023-01-31

# %% [markdown]
# ## Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# The first and foremost necessary library that needs to be imported is **pandas**
#
# `import pandas as pd`
