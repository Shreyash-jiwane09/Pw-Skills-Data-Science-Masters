# %% [markdown]
# ## Q1. What is Web Scraping? Why is it Used? Give three areas where Web Scraping is used to get data.

# %% [markdown]
# Web Scraping is a technique to extract a large amount of data from several websites. The term "scraping" refers to obtaining the information from another source (webpages) and saving it into a local file. For example: Suppose you are working on a project called "Phone comparing website," where you require the price of mobile phones, ratings, and model names to make comparisons between the different mobile phones. If you collect these details by checking various sites, it will take much time. In that case, web scrapping plays an important role where by writing a few lines of code you can get the desired results.
#
# ![image.png](attachment:image.png)
#
# Web Scrapping extracts the data from websites in the unstructured format. It helps to collect these unstructured data and convert it in a structured form.
#
# Startups prefer web scrapping because it is a cheap and effective way to get a large amount of data without any partnership with the data selling company.
#
# ### Why Web Scrapping?
#
# ![image-2.png](attachment:image-2.png)
#
# As we have discussed above, web scrapping is used to extract the data from websites. But we should know how to use that raw data. That raw data can be used in various fields. Let's have a look at the usage of web scrapping:
#
# 1. Dynamic Price Monitoring:
# It is widely used to collect data from several online shopping sites and compare the prices of products and make profitable pricing decisions. Price monitoring using web scrapped data gives the ability to the companies to know the market condition and facilitate dynamic pricing. It ensures the companies they always outrank others.
#
# 2. Market Research:
# Web Scrapping is perfectly appropriate for market trend analysis. It is gaining insights into a particular market. The large organization requires a great deal of data, and web scrapping provides the data with a guaranteed level of reliability and accuracy.
#
# 3. Email Gathering:
#
# Many companies use personals e-mail data for email marketing. They can target the specific audience for their marketing.

# %% [markdown]
# ## Q2. What are the different methods used for Web Scraping?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### Method 1: BeautifulSoup and Requests for Web Scraping:
# The first method uses the popular BeautifulSoup and Requests libraries. These tools make it easy to analyze HTML and navigate web page structure.
#
# #### Method 2: ScraPy for Web Scraping :
# ScraPy is a powerful and flexible web scraping framework
#
# #### Method 3: Selenium for Web Scraping:
# Selenium is often used for dynamic web scraping.The key to Selenium is in its Chrome options, which are settings for customizing the behavior of the Chrome browser controlled by Selenium WebDriver. These options enable control over aspects like incognito mode, window size, notifications, and more.
#
# #### Method 4: Requests and lxml for Web Scraping:
# lxml is a Python library linking with C libraries libxml2 and libxslt, combining speed and XML features with a simple native Python API, similar to ElementTree but with added benefits.

# %% [markdown]
# ## Q3. What is Beautiful Soup? Why is it used?

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.
#
#
# Beautiful Soup is useful for web scraping, data mining, and screen scraping. It can be used to extract data from HTML and XML files, and it can also be used to modify those files.
#
# **Here are some of the reasons why we use Beautiful Soup in Python:**
# 1. It is a powerful and flexible tool for parsing HTML and XML documents.
# 2. It is easy to use and has a well-documented API.
# 3. It is relatively fast and efficient.
# 4. It is well-maintained and actively developed.
# 5. It is free and open-source software.

# %% [markdown]
# ## Q4. Why is flask used in this Web Scraping project?

# %% [markdown]
# Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries. It has no database abstraction layer, form validation, or any other components where pre-existing third-party libraries provide common functions.
#
# **Here are some of the reasons why Flask is used in web scraping:**
# 1. Lightweight:
# Flask is a lightweight framework that does not require a lot of dependencies, making it ideal for web scraping projects.
#
# 2. Easy to use:
# Flask is easy to learn and use, even for beginners.
#
# 3. Flexible:
# Flask is a flexible framework that can be used to create a wide variety of web applications, including web scrapers.
#
# 4. Scalable:
# Flask is a scalable framework that can be used to create web scrapers that can handle a large amount of traffic.

# %% [markdown]
# ## Q5. Write the names of AWS services used in this project. Also, explain the use of each service.

# %% [markdown]
# During the deployment of project on AWS cloud we used 2 services of AWS cloud.They are :
# 1. Code Pipeline
# 2. Bean Stalk
